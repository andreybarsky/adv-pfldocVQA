# %%
try:
    import secmlt
except ImportError:
   # %pip install secml-torch[foolbox,adv_lib]
# Out:
# ERROR: Could not find a version that satisfies the requirement secml-torch[adv_lib,foolbox] (from versions: none)
# ERROR: No matching distribution found for secml-torch[adv_lib,foolbox]
# Note: you may need to restart the kernel to use updated packages.
